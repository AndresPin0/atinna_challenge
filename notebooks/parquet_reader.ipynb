# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 50)

df = pd.read_parquet("../data/reto.parquet")

df.head()
# Out:
#                                  id attachments            author  \
# 0  c6adb4630994bdee807d387382d526bc          []  Consulta Popular
# 1  9fee3686bd7f2fd45d381a9b388dfb5e          []  Consulta Popular
# 2  9adb9324d96a398905767afcf428e956          []  Daniel Hernandez
# 3  be6ed61346de9fc96e3e797d70d275a9          []
# 4  4a893f2667aa8eddb4c84fcd09fcd43f          []
#
#   authorCategory authorCategoryId authorId authorURL automateProjectId  \
# 0
# 1
# 2
# 3
# 4
#
#   caption                                            context contextTitle  \
# 0            El camino hacia la consulta popular en Colombia
# 1                          La Consulta popular constituyente
# 2          Empleo juvenil, frente del mercado laboral que...
# 3          Petro da marcha atrás con consulta sobre <q>re...
# 4          Petro firmó decreto de la <q>reforma</q> <q>la...
#
#   country      createdAt description engagementRate facebookAdAccountId  \
# 0      co  1750834500000
# ...

# %%
df[df["id"] == "tikapi_7520805329748151557"]
# Out:
#                              id  \
# 930  tikapi_7520805329748151557
#
#                                            attachments  \
# 930  [{'name': 'https://v45-eu.tiktokcdn.com/962e6e...
#
#                                author authorCategory authorCategoryId  \
# 930  FRANK PORTILLA (@frankportilla0)
#
#                 authorId authorURL automateProjectId caption context  \
# 930  6812248190717543430
#
#     contextTitle country      createdAt description engagementRate  \
# 930                       1751073950000                      84.85
#
#     facebookAdAccountId facebookIds facebookMessengerThreadId facebookPageId  \
# 930                              []
#
#       group hasImageOrVideo            host ignored  \
# 930  tiktok            True  www.tiktok.com   False
#
#                                                  image influenceScore  ...  \
# 930  https://sentione.com/app/assets/statements?sta...             10  ...
#
# ...
